// %%
.x gate2.C
// Out:
// LINUX
//
// Gamma-Gamma two-fold matrix data analysis Code GATE2
// Author: Zhihuan Li, Peking University
// Last modified on Dec. 4, 2021
// Find the last updates from [https://github.com/zhihuanli/gamma-gamma-coincidence-analysis/tree/master/Gate2]
//
// ROOT file: gate2matrix.root
// 2D-histogram: hg2xyp
// Range of X/Y: 0 - 3999
//
// Current settings:
// ncanvas = 5
// xmin = 0, xmax= 2000
// npeaks = 30
// dge = 2
//
// help() for short instructions
//
// 0 1 gtpj_0  [Total Projection Sepctrum (0 - 666) keV ]
// 0 1 gtpj_1  [Total Projection Sepctrum (666 - 1332) keV ]
// 0 1 gtpj_2  [Total Projection Sepctrum (1332 - 1998) keV ]

// %%
setxrange(100,1500);

// %%
gm(535,596)
// Out:
// 1 1 g535_0  [Gated on 535.0 keV (533.0 - 537.0)]
// 1 2 g596_0  [Gated on 596.0 keV (594.0 - 598.0)]

// %%
setnpeaks(60)

// %%
gm(535,596)
// Out:
// 2 1 g535_1  [Gated on 535.0 keV (533.0 - 537.0)]
// 2 2 g596_1  [Gated on 596.0 keV (594.0 - 598.0)]

// %%
gmxr(100,900,535,596)
// Out:
// 3 1 g535_2  [Gated on 535.0 keV (533.0 - 537.0)]
// 3 2 g596_2  [Gated on 596.0 keV (594.0 - 598.0)]

// %%
help()
// Out:
// ....oooOO0OOooo........oooOO0OOooo........oooOO0OOooo........oooOO0OOooo......
// Setup, changes will take effect for the next drawing.
//    setxrange(int xmin1, int xmax1)        - Change the viewing range of x-axis for all histograms.
//    setnpeaks(int npeaks1=30)              - Change the number of peaks marked in a histogram.
//    setncanvas(int ncanvas=5)              - Change the maximum number of canvas avaliable.
//    setgatewidth(int dge=2)                - Change range of gate to peak-dge to peak+dge.
//    showSettings()                         - Show current parameter settings.
// ....oooOO0OOooo........oooOO0OOooo........oooOO0OOooo........oooOO0OOooo......
// Show a gated-spectrum.
//    gs(float ge1,int npad=4)
// Show gated-spectra
//    gm(float ge1, [float ge2], [float ge3], [float ge4])
//    gm(TH1* h1, [TH1* h2],[TH1* h3],[TH1* h4])
// Show total projection sepctrum.
//    tpjm(int npad)
// Show a spectrum gated from ge1 to ge2
// ...

// %%
histlist()
// Out:
// OBJ: TList	TList	Doubly linked list : 0
//  OBJ: TH1D	gtpj_0	Total Projection Sepctrum (0 - 666) keV  : 0 at: 0x7fc6f0b4c340
//  OBJ: TH1D	gtpj_1	Total Projection Sepctrum (666 - 1332) keV  : 0 at: 0x7fc6f0ca1360
//  OBJ: TH1D	gtpj_2	Total Projection Sepctrum (1332 - 1998) keV  : 0 at: 0x7fc6f0ca9380
//  OBJ: TH1D	g535_0	Gated on 535.0 keV (533.0 - 537.0) : 0 at: 0x7fc6e800ba50
//  OBJ: TH1D	g596_0	Gated on 596.0 keV (594.0 - 598.0) : 0 at: 0x7fc6e800e240
//  OBJ: TH1D	g535_1	Gated on 535.0 keV (533.0 - 537.0) : 0 at: 0x7fc6e800d040
//  OBJ: TH1D	g596_1	Gated on 596.0 keV (594.0 - 598.0) : 0 at: 0x7fc6e80484b0
//  OBJ: TH1D	g535_2	Gated on 535.0 keV (533.0 - 537.0) : 0 at: 0x7fc6e8048030
//  OBJ: TH1D	g596_2	Gated on 596.0 keV (594.0 - 598.0) : 0 at: 0x7fc6e80793e0

// %%
gmxr(100,1200,gtpj_0,g535_0)
// Out:
// 4 2 gtpj_0  [Total Projection Sepctrum (0 - 666) keV ]
// 4 2 g535_0  [Gated on 535.0 keV (533.0 - 537.0)]

// %%
saveHist(g535_0,"g535.root")
// Out:
// Write g535_0 to g535.root

// %%
gadd(535,596)
// Out:
// 0 1 g535_3  [Gated on 535.0 keV (533.0 - 537.0)]
// 0 2 g596_3  [Gated on 596.0 keV (594.0 - 598.0)]
// 0 3 gadd_0  [Add gates of 535.0 596.0 keV]

// %%
gaddxr(100,900,535,842)
// Out:
// 1 1 g535_4  [Gated on 535.0 keV (533.0 - 537.0)]
// 1 2 g842_0  [Gated on 842.0 keV (840.0 - 844.0)]
// 1 3 gadd_1  [Add gates of 535.0 842.0 keV]

// %%
gmxr(100,1000,gadd_1,gadd_0)
// Out:
// 2 3 gadd_1  [Add gates of 535.0 842.0 keV]
// 2 3 gadd_0  [Add gates of 535.0 596.0 keV]
