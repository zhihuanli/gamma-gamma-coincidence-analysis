// %%
.x gate3.C
// Out:
// LINUX
//
// Gamma-Gamma-Gamma three-fold matrix data analysis Code GATE3
// Author: Zhihuan Li, Peking University
// Last modified on Dec. 18, 2021
// Find the last updates from [https://github.com/zhihuanli/gamma-gamma-coincidence-analysis/tree/master/Gate3]
//
// g3hist ROOT file: g3hist.root
// g3histbkg ROOT file: g3histbkg.root
// Range of X/Y/Z: 0 - 1999
//
// Current settings:
// ncanvas = 5
// xmin = 0, xmax= 2000
// npeaks = 30
// dge = 2
//
// help() for short instructions
//
// 0 1 gtpj_0  [Total Projection Sepctrum (0 - 666) keV ]
// 0 1 gtpj_1  [Total Projection Sepctrum (666 - 1332) keV ]
// 0 1 gtpj_2  [Total Projection Sepctrum (1332 - 1998) keV ]

// %%
help()
// Out:
// ....oooOO0OOooo........oooOO0OOooo........oooOO0OOooo........oooOO0OOooo......
// Setup, changes will take effect for the next drawing.
//    setxrange(int xmin1, int xmax1)        - Change the viewing range of x-axis for all histograms.
//    setnpeaks(int npeaks1=30)              - Change the number of peaks marked in a histogram.
//    setncanvas(int ncanvas=5)              - Change the maximum number of canvas avaliable.
//    setgatewidth(int dge=2)                - Change range of gate to peak-dge to peak+dge.
//    showSettings()                         - Show current parameter settings.
// ....oooOO0OOooo........oooOO0OOooo........oooOO0OOooo........oooOO0OOooo......
//   g2m(float ge0a, float ge0b,[float ge1a, float ge1b,float ge2a, float ge2b,float ge3a, float ge3b])
//    g2m(TH1* h1, [TH1* h2],[TH1* h3],[TH1* h4])
// Show total projection sepctrum.
//    tpjm(int npad)
// Show gated spectra with specified the x-axis range.
// ...

// %%
g2mxr(100,1500,535,596)
// Out:
// 1 1 gg535_596_0  [Gated on 535.0 keV & 596.0 keV]

// %%
g2mxr(100,1500,535,596,402,841)
// Out:
// 2 1 gg535_596_1  [Gated on 535.0 keV & 596.0 keV]
// 2 2 gg402_841_0  [Gated on 402.0 keV & 841.0 keV]

// %%
tpjmxr(100,1500,1)
// Out:
// 3 2 gtpj_3  [Total Projection Sepctrum (100 - 1500) keV ]

// %%
tpjmxr(100,1500,1)
// Out:
// 4 2 gtpj_4  [Total Projection Sepctrum (100 - 1500) keV ]

// %%
setxrange(100,1000)

// %%
tpjm(1)
// Out:
// 0 2 gtpj_5  [Total Projection Sepctrum (100 - 1000) keV ]

// %%
setnpeaks(50)

// %%
tpjmxr(100,1000,2)
// Out:
// 1 2 gtpj_6  [Total Projection Sepctrum (100 - 550) keV ]
// 1 2 gtpj_7  [Total Projection Sepctrum (550 - 1000) keV ]
