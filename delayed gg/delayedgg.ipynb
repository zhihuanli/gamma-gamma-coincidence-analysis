// %% [markdown]
// ## 3.delayed $\gamma-\gamma$ analysis

// %%
.x agg.C
// Out:
// load ROOT file: d46_123gg.root
// 0 1 atpj0  [ae-net peaks from decay of mother nuclei]
// 0 1 atpj1  [ae-net peaks from decay of mother nuclei]
// 1 1 btpj2  [ge-net peaks from decay of daughter nuclei]
// 1 1 btpj3  [ge-net peaks from decay of daughter nuclei]

// %%
setnpeaks(10);

// %%
gbm(123,263)
// Out:
// 2 1 gb123_4  [gated on be=123.0 keV]
// 2 2 gb263_5  [gated on be=263.0 keV]

// %%
gbm(409,592)
// Out:
// 3 1 gb409_6  [gated on be=409.0 keV]
// 3 2 gb592_7  [gated on be=592.0 keV]

// %%
gam(383,593)
// Out:
// 4 1 ga383_8  [gated on ae=383.0 keV]
// 4 2 ga593_9  [gated on ae=593.0 keV]

// %%
gam(325,1009)
// Out:
// 5 1 ga325_10  [gated on ae=325.0 keV]
// 5 2 ga1009_11  [gated on ae=1009.0 keV]

// %%
gam(629,713)
// Out:
// 6 1 ga629_12  [gated on ae=629.0 keV]
// 6 2 ga713_13  [gated on ae=713.0 keV]

// %%
newcanvas(1)

// %%
ga(1077)
// Out:
// 7 1 ga1077_14  [gated on ae=1077.0 keV]
// (TString) "ga1077_14"[9]
